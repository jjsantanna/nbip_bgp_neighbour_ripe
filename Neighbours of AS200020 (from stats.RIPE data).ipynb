# %% [markdown]
# # Analysing the data from https://stat.ripe.net/data/asn-neighbours-history/data.json?resource=AS200020
# - ASn that are neighbours of AS200020
# - 89 days of observation (from 06-Jan till 06-Apr)

# %% [markdown]
# ## Getting the json from RIPE

# %%
import pandas as pd 
import urllib.request
import json

url_ripe = "https://stat.ripe.net/data/asn-neighbours-history/data.json?resource=AS200020"
with urllib.request.urlopen(url_ripe) as url:
    df = pd.DataFrame.from_dict(json.loads(url.read().decode()), orient='index')

df.tail()
# Out:
#                                                                   0
# data_call_status                     supported - connecting to ursa
# process_time                                                     36
# build_version                                          2018.4.5.317
# query_id          20180406135433-3127ae07-9372-4335-9841-fa83c83...
# data              {'resource': '200020', 'query_starttime': '201...

# %% [markdown]
# ## Filtering only the field 'data' (in the raw json)

# %%
df_data = pd.DataFrame.from_dict(df[0]['data'])
df_data.head()
# Out:
#          earliest_time          latest_time  \
# 0  2000-08-01T00:00:00  2018-04-06T00:00:00
# 1  2000-08-01T00:00:00  2018-04-06T00:00:00
# 2  2000-08-01T00:00:00  2018-04-06T00:00:00
# 3  2000-08-01T00:00:00  2018-04-06T00:00:00
# 4  2000-08-01T00:00:00  2018-04-06T00:00:00
#
#                                           neighbours        query_endtime  \
# 0  {'neighbour': 174, 'timelines': [{'endtime': '...  2018-04-06T00:00:00
# 1  {'neighbour': 1103, 'timelines': [{'endtime': ...  2018-04-06T00:00:00
# 2  {'neighbour': 1126, 'timelines': [{'endtime': ...  2018-04-06T00:00:00
# 3  {'neighbour': 1764, 'timelines': [{'endtime': ...  2018-04-06T00:00:00
# 4  {'neighbour': 2018, 'timelines': [{'endtime': ...  2018-04-06T00:00:00
#
#        query_starttime resource
# 0  2018-01-06T00:00:00   200020
# 1  2018-01-06T00:00:00   200020
# 2  2018-01-06T00:00:00   200020
# 3  2018-01-06T00:00:00   200020
# 4  2018-01-06T00:00:00   200020

# %% [markdown]
# ## Spliting the column 'neighbours'

# %%
df_data['as_neighbour']=df_data['neighbours'].apply(lambda x: x['neighbour'])
df_data['endtime']=pd.to_datetime(pd.Series(df_data['neighbours'].apply(lambda x: x['timelines'][0]['endtime'])))
df_data['starttime']=pd.to_datetime(pd.Series(df_data['neighbours'].apply(lambda x: x['timelines'][0]['starttime'])))
df_data['delta_time'] = df_data['endtime']-df_data['starttime']

# %% [markdown]
# ## Sorting by the time that a AS was observed as neighbour ('delta_time')

# %%
df_data = df_data.sort_values(by='delta_time',ascending=True).reset_index(drop=True)
df_data.head()
# Out:
#          earliest_time          latest_time  \
# 0  2000-08-01T00:00:00  2018-04-06T00:00:00
# 1  2000-08-01T00:00:00  2018-04-06T00:00:00
# 2  2000-08-01T00:00:00  2018-04-06T00:00:00
# 3  2000-08-01T00:00:00  2018-04-06T00:00:00
# 4  2000-08-01T00:00:00  2018-04-06T00:00:00
#
#                                           neighbours        query_endtime  \
# 0  {'neighbour': 34968, 'timelines': [{'endtime':...  2018-04-06T00:00:00
# 1  {'neighbour': 31615, 'timelines': [{'endtime':...  2018-04-06T00:00:00
# 2  {'neighbour': 48886, 'timelines': [{'endtime':...  2018-04-06T00:00:00
# 3  {'neighbour': 49453, 'timelines': [{'endtime':...  2018-04-06T00:00:00
# 4  {'neighbour': 42158, 'timelines': [{'endtime':...  2018-04-06T00:00:00
#
#        query_starttime resource  as_neighbour             endtime  \
# 0  2018-01-06T00:00:00   200020         34968 2018-01-11 16:00:00
# 1  2018-01-06T00:00:00   200020         31615 2018-03-14 00:00:00
# 2  2018-01-06T00:00:00   200020         48886 2018-03-27 16:00:00
# 3  2018-01-06T00:00:00   200020         49453 2018-03-27 16:00:00
# 4  2018-01-06T00:00:00   200020         42158 2018-02-01 00:00:00
#
#             starttime      delta_time
# 0 2018-01-11 16:00:00 0 days 00:00:00
# 1 2018-03-14 00:00:00 0 days 00:00:00
# 2 2018-03-27 16:00:00 0 days 00:00:00
# 3 2018-03-27 16:00:00 0 days 00:00:00
# 4 2018-01-30 16:00:00 1 days 08:00:00

# %% [markdown]
# ## Enriching the ASn (with team cymru)

# %%
from subprocess import Popen, PIPE
import os.path
import random
import time 

def teamcymru_asn_lookup (asn):
    command = 'whois -h whois.cymru.com " -v AS' + str(asn) + '"'
    p = Popen(command, universal_newlines=True, shell=True, stdout=PIPE, stderr=PIPE)
    output,error = p.communicate()
    p.wait()
    return output.split('\n')[1].split(' | ')

df_data['asn_info'] = df_data['as_neighbour'].apply(lambda x: teamcymru_asn_lookup(x))

# %% [markdown]
# ## Splitting collumn 'asn_info'

# %%
df_data['asn_country']=df_data['asn_info'].apply(lambda x: x[1])
df_data['asn_name']=df_data['asn_info'].apply(lambda x: x[4])

# %% [markdown]
# ## Filtering only ASN located in the Netherlands

# %%
df_only_nl_asn = df_data[df_data['asn_country']=='NL'][['as_neighbour','delta_time','asn_country','asn_name']].reset_index(drop=True)
df_only_nl_asn
# Out:
#     as_neighbour       delta_time asn_country  \
# 0          34968  0 days 00:00:00          NL
# 1          31615  0 days 00:00:00          NL
# 2          48886  0 days 00:00:00          NL
# 3          49453  0 days 00:00:00          NL
# 4          42158  1 days 08:00:00          NL
# 5          48522  1 days 08:00:00          NL
# 6          48635 15 days 16:00:00          NL
# 7          20495 17 days 00:00:00          NL
# 8          39591 21 days 08:00:00          NL
# 9          25151 23 days 08:00:00          NL
# 10        203256 25 days 08:00:00          NL
# 11         49685 26 days 16:00:00          NL
# 12         20559 30 days 16:00:00          NL
# 13         43366 51 days 08:00:00          NL
# 14         59545 54 days 00:00:00          NL
# 15         49405 62 days 16:00:00          NL
# 16        198089 64 days 08:00:00          NL
# 17         29396 67 days 08:00:00          NL
# 18         21221 70 days 00:00:00          NL
# 19         25542 77 days 08:00:00          NL
# 20         21155 80 days 08:00:00          NL
# 21         16243 80 days 16:00:00          NL
# 22         39647 89 days 16:00:00          NL
# 23         42315 89 days 16:00:00          NL
# 24          8283 89 days 16:00:00          NL
# 25          6777 89 days 16:00:00          NL
# 26          1103 89 days 16:00:00          NL
# 27         12859 89 days 16:00:00          NL
# 28         24586 89 days 16:00:00          NL
# 29         20847 89 days 16:00:00          NL
# 30         20562 89 days 16:00:00          NL
# 31         15879 89 days 16:00:00          NL
# 32         15435 89 days 16:00:00          NL
#
#                                              asn_name
# 0                                           IUNXI, NL
# 1                                       TMO-NL-AS, NL
# 2   CSNET-AS +------------------------------------...
# 3                                     GLOBALLAYER, NL
# 4                                       SENTIA-AS, NL
# 5                                CGI-NEDERLAND-BV, NL
# 6                                        ASTRALUS, NL
# 7                              WEDARE wd6.NET B.V, NL
# 8                                        GLOBAL-E, NL
# 9                                         CYSO-AS, NL
# 10                                  ASBUDGETPHONE, NL
# 11                            ITIS-AS Signet B.V., NL
# 12                                  FUNDAMENTS-AS, NL
# 13                                           OSSO, NL
# 14                          VXBITS VXbits Network, NL
# 15                                  MOTTO-VOIP-AS, NL
# 16                                      IPVN-AS01, NL
# 17             UNET Unet Network, The Netherlands, NL
# 18                    INFOPACT-AS The Netherlands, NL
# 19                             DENIT-AS Amsterdam, NL
# 20                         ASN-PROSERVE Amsterdam, NL
# 21             VIRTU-AS Enschede, The Netherlands, NL
# 22                                  REDHOSTING-AS, NL
# 23                                   TWINFIELD-AS, NL
# 24  COLOCLUE-AS Netwerkvereniging Coloclue, Amster...
# 25                                      AMS-IX-RS, NL
# 26            SURFNET-NL SURFnet, The Netherlands, NL
# 27                                  NL-BIT BIT BV, NL
# 28        NL-INTERMAX Intermax Cloudsourcing B.V., NL
# 29                                    PREVIDER-AS, NL
# 30  OPEN-PEERING-AS Open Peering Initiative, Amste...
# 31                           KPN-INTERNEDSERVICES, NL
# 32               KABELFOON CAIW Autonomous System, NL

# %% [markdown]
# ## Keeping only NBIP neighbors that are less than 89 days
# which I admit that are connected to NBIP just to receive protection!

# %%
potential_as_protected = df_only_nl_asn[df_only_nl_asn['delta_time']<pd.to_timedelta('89 days')].reset_index(drop=True)
display(potential_as_protected)
# Out:
#     as_neighbour       delta_time asn_country  \
# 0          34968  0 days 00:00:00          NL
# 1          31615  0 days 00:00:00          NL
# 2          48886  0 days 00:00:00          NL
# 3          49453  0 days 00:00:00          NL
# 4          42158  1 days 08:00:00          NL
# 5          48522  1 days 08:00:00          NL
# 6          48635 15 days 16:00:00          NL
# 7          20495 17 days 00:00:00          NL
# 8          39591 21 days 08:00:00          NL
# 9          25151 23 days 08:00:00          NL
# 10        203256 25 days 08:00:00          NL
# 11         49685 26 days 16:00:00          NL
# 12         20559 30 days 16:00:00          NL
# 13         43366 51 days 08:00:00          NL
# 14         59545 54 days 00:00:00          NL
# 15         49405 62 days 16:00:00          NL
# 16        198089 64 days 08:00:00          NL
# 17         29396 67 days 08:00:00          NL
# 18         21221 70 days 00:00:00          NL
# 19         25542 77 days 08:00:00          NL
# 20         21155 80 days 08:00:00          NL
# 21         16243 80 days 16:00:00          NL
#
#                                              asn_name
# 0                                           IUNXI, NL
# 1                                       TMO-NL-AS, NL
# 2   CSNET-AS +------------------------------------...
# 3                                     GLOBALLAYER, NL
# 4                                       SENTIA-AS, NL
# 5                                CGI-NEDERLAND-BV, NL
# 6                                        ASTRALUS, NL
# 7                              WEDARE wd6.NET B.V, NL
# 8                                        GLOBAL-E, NL
# 9                                         CYSO-AS, NL
# 10                                  ASBUDGETPHONE, NL
# 11                            ITIS-AS Signet B.V., NL
# 12                                  FUNDAMENTS-AS, NL
# 13                                           OSSO, NL
# 14                          VXBITS VXbits Network, NL
# 15                                  MOTTO-VOIP-AS, NL
# 16                                      IPVN-AS01, NL
# 17             UNET Unet Network, The Netherlands, NL
# 18                    INFOPACT-AS The Netherlands, NL
# 19                             DENIT-AS Amsterdam, NL
# 20                         ASN-PROSERVE Amsterdam, NL
# 21             VIRTU-AS Enschede, The Netherlands, NL
